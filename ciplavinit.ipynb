# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
train=pd.read_csv("../input/cipdata/train.csv")
test=pd.read_csv("../input/cipdata/test.csv")

# %%
train.columns
# Out:
# Index(['Customer ID', 'Name', 'Gender', 'Age', 'Income (USD)',
#        'Income Stability', 'Profession', 'Type of Employment', 'Location',
#        'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score',
#        'No. of Defaults', 'Has Active Credit Card', 'Property ID',
#        'Property Age', 'Property Type', 'Property Location', 'Co-Applicant',
#        'Property Price', 'Loan Sanction Amount (USD)'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Customer ID', 'Name', 'Gender', 'Age', 'Income (USD)',
#        'Income Stability', 'Profession', 'Type of Employment', 'Location',
#        'Loan Amount Request (USD)', 'Current Loan Expenses (USD)',
#        'Expense Type 1', 'Expense Type 2', 'Dependents', 'Credit Score',
#        'No. of Defaults', 'Has Active Credit Card', 'Property ID',
#        'Property Age', 'Property Type', 'Property Location', 'Co-Applicant',
#        'Property Price'],
#       dtype='object')

# %%
X=train.iloc[:,:-1]
X.drop('Customer ID',axis=1,inplace=True)
X.drop('Name',axis=1,inplace=True)
X.drop('Gender',axis=1,inplace=True)
X.drop('Property ID',axis=1,inplace=True)
X
# Out:
#        Age  Income (USD) Income Stability            Profession  \
# 0       56       1933.05              Low               Working
# 1       32       4952.91              Low               Working
# 2       65        988.19             High             Pensioner
# 3       65           NaN             High             Pensioner
# 4       31       2614.77              Low               Working
# ...    ...           ...              ...                   ...
# 29995   38       4969.41              Low  Commercial associate
# 29996   20       1606.88              Low               Working
# 29997   49           NaN              Low               Working
# 29998   38       2417.71              Low               Working
# 29999   63       3068.24             High             Pensioner
#
#           Type of Employment    Location  Loan Amount Request (USD)  \
# 0                Sales staff  Semi-Urban                   72809.58
# ...

# %%
y=train.iloc[:,-1]
y
# Out:
# 0         54607.18
# 1         37469.98
# 2         36474.43
# 3         56040.54
# 4         74008.28
#            ...
# 29995     68992.11
# 29996     46616.60
# 29997     61057.56
# 29998     99766.87
# 29999    117217.90
# Name: Loan Sanction Amount (USD), Length: 30000, dtype: float64

# %%
#'Customer ID','Name','Gender','Property ID'

# %%
X_test=test.iloc[:,:]
X_test.drop('Customer ID',axis=1,inplace=True)
X_test.drop('Name',axis=1,inplace=True)
X_test.drop('Gender',axis=1,inplace=True)
X_test.drop('Property ID',axis=1,inplace=True)

X_test
# Out:
#        Age  Income (USD) Income Stability            Profession  \
# 0       47       3472.69              Low  Commercial associate
# 1       57       1184.84              Low               Working
# 2       52       1266.27              Low               Working
# 3       65       1369.72             High             Pensioner
# 4       60       1939.23             High             Pensioner
# ...    ...           ...              ...                   ...
# 19995   19       1349.60              Low  Commercial associate
# 19996   22       2019.78              Low               Working
# 19997   19       2252.03              Low               Working
# 19998   21       1845.35              Low               Working
# 19999   21       5233.16              Low               Working
#
#       Type of Employment    Location  Loan Amount Request (USD)  \
# 0               Managers  Semi-Urban                  137088.98
# 1            Sales staff       Rural                  104771.59
# ...

# %%
X.columns
# Out:
# Index(['Age', 'Income (USD)', 'Income Stability', 'Profession',
#        'Type of Employment', 'Location', 'Loan Amount Request (USD)',
#        'Current Loan Expenses (USD)', 'Expense Type 1', 'Expense Type 2',
#        'Dependents', 'Credit Score', 'No. of Defaults',
#        'Has Active Credit Card', 'Property Age', 'Property Type',
#        'Property Location', 'Co-Applicant', 'Property Price'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['Income Stability']=le.fit_transform(X['Income Stability'].astype(str))
X['Profession']=le.fit_transform(X['Profession'].astype(str))
X['Type of Employment']=le.fit_transform(X['Type of Employment'].astype(str))
X['Location']=le.fit_transform(X['Location'].astype(str))

X['Expense Type 1']=le.fit_transform(X['Expense Type 1'].astype(str))
X['Expense Type 2']=le.fit_transform(X['Expense Type 2'].astype(str))
X['Has Active Credit Card']=le.fit_transform(X['Has Active Credit Card'].astype(str))
X['Property Location']=le.fit_transform(X['Property Location'].astype(str))

#X['customer_id']=le.fit_transform(X['customer_id'].astype(str))
X
# Out:
#        Age  Income (USD)  Income Stability  Profession  Type of Employment  \
# 0       56       1933.05                 1           7                  14
# 1       32       4952.91                 1           7                  18
# 2       65        988.19                 0           3                  18
# 3       65           NaN                 0           3                  18
# 4       31       2614.77                 1           7                   6
# ...    ...           ...               ...         ...                 ...
# 29995   38       4969.41                 1           1                  10
# 29996   20       1606.88                 1           7                   8
# 29997   49           NaN                 1           7                  14
# 29998   38       2417.71                 1           7                  16
# 29999   63       3068.24                 0           3                  18
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X_test['Income Stability']=le.fit_transform(X_test['Income Stability'].astype(str))
X_test['Profession']=le.fit_transform(X_test['Profession'].astype(str))
X_test['Type of Employment']=le.fit_transform(X_test['Type of Employment'].astype(str))
X_test['Location']=le.fit_transform(X_test['Location'].astype(str))

X_test['Expense Type 1']=le.fit_transform(X_test['Expense Type 1'].astype(str))
X_test['Expense Type 2']=le.fit_transform(X_test['Expense Type 2'].astype(str))
X_test['Has Active Credit Card']=le.fit_transform(X_test['Has Active Credit Card'].astype(str))
X_test['Property Location']=le.fit_transform(X_test['Property Location'].astype(str))


#X['customer_id']=le.fit_transform(X['customer_id'].astype(str))
X_test
# Out:
#        Age  Income (USD)  Income Stability  Profession  Type of Employment  \
# 0       47       3472.69                 1           0                  10
# 1       57       1184.84                 1           6                  14
# 2       52       1266.27                 1           6                  18
# 3       65       1369.72                 0           2                  18
# 4       60       1939.23                 0           2                  18
# ...    ...           ...               ...         ...                 ...
# 19995   19       1349.60                 1           0                  18
# 19996   22       2019.78                 1           6                   3
# 19997   19       2252.03                 1           6                   3
# 19998   21       1845.35                 1           6                  18
# 19999   21       5233.16                 1           6                   8
#
# ...

# %%
#y2=le.fit_transform(y2.astype(str))

#y2
X.mean(axis = 0)
# Out:
# Age                                40.092300
# Income (USD)                     2630.574417
# Income Stability                    0.970567
# Profession                          4.804900
# Type of Employment                 10.315400
# Location                            0.925367
# Loan Amount Request (USD)       88826.333855
# Current Loan Expenses (USD)       400.936876
# Expense Type 1                      0.359533
# Expense Type 2                      0.672667
# Dependents                          2.253027
# Credit Score                      739.885381
# No. of Defaults                     0.193933
# Has Active Credit Card              1.085267
# Property Age                     2631.119440
# Property Type                       2.460067
# Property Location                   0.996233
# Co-Applicant                       -4.743867
# Property Price                 131759.680252
# dtype: float64

# %%
X.isna().sum()
# Out:
# Age                               0
# Income (USD)                   4576
# Income Stability                  0
# Profession                        0
# Type of Employment                0
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card            0
# Property Age                   4850
# Property Type                     0
# Property Location                 0
# Co-Applicant                      0
# Property Price                    0
# dtype: int64

# %%
X['Income (USD)'].fillna(2630, inplace=True)
X['Current Loan Expenses (USD)'].fillna(400, inplace=True)
X['Dependents'].fillna(2, inplace=True)
X['Credit Score'].fillna(739, inplace=True)
X['Property Age'].fillna(2631, inplace=True)

# %%
X.isna().sum()
# Out:
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property Age                   0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# Age                               0
# Income (USD)                    750
# Income Stability                  0
# Profession                        0
# Type of Employment                0
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)      83
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     1142
# Credit Score                    743
# No. of Defaults                   0
# Has Active Credit Card            0
# Property Age                    892
# Property Type                     0
# Property Location                 0
# Co-Applicant                      0
# Property Price                    0
# dtype: int64

# %%
X_test.mean(axis = 0)
# Out:
# Age                               39.940500
# Income (USD)                    2536.995394
# Income Stability                   0.956350
# Profession                         3.835800
# Type of Employment                10.216750
# Location                           0.933250
# Loan Amount Request (USD)      88859.076706
# Current Loan Expenses (USD)      408.462359
# Expense Type 1                     0.359200
# Expense Type 2                     0.669150
# Dependents                         2.251246
# Credit Score                     738.821538
# No. of Defaults                    0.189500
# Has Active Credit Card             1.093200
# Property Age                    2534.102003
# Property Type                      2.471900
# Property Location                  0.989250
# dtype: float64

# %%
X_test['Income (USD)'].fillna(2536, inplace=True)
X_test['Current Loan Expenses (USD)'].fillna(408, inplace=True)
X_test['Dependents'].fillna(2, inplace=True)
X_test['Credit Score'].fillna(738, inplace=True)
X_test['Property Age'].fillna(2534, inplace=True)

# %%
y=train.iloc[:,-1]
y
# Out:
# 0         54607.18
# 1         37469.98
# 2         36474.43
# 3         56040.54
# 4         74008.28
#            ...
# 29995     68992.11
# 29996     46616.60
# 29997     61057.56
# 29998     99766.87
# 29999    117217.90
# Name: Loan Sanction Amount (USD), Length: 30000, dtype: float64

# %%
y.isna().sum()
# Out:
# 340

# %%
y.mean(axis = 0)
# Out:
# 47649.342208361435

# %%
y.fillna(47649, inplace=True)

# %% [markdown]
# from sklearn.svm import SVC
# svc=SVC(kernel='poly',degree=3)
# svc.fit(X,y2)
# print(svc.score(X,y2))

# %%
X_t = X_test.apply(pd.to_numeric, errors='coerce')

# %%
X_t.isna().sum()
# Out:
# Age                              0
# Income (USD)                     0
# Income Stability                 0
# Profession                       0
# Type of Employment               0
# Location                         0
# Loan Amount Request (USD)        0
# Current Loan Expenses (USD)      0
# Expense Type 1                   0
# Expense Type 2                   0
# Dependents                       0
# Credit Score                     0
# No. of Defaults                  0
# Has Active Credit Card           0
# Property Age                     0
# Property Type                    0
# Property Location                0
# Co-Applicant                    77
# Property Price                 168
# dtype: int64

# %%
X_t.mean(axis = 0)
# Out:
# Age                                39.940500
# Income (USD)                     2536.958067
# Income Stability                    0.956350
# Profession                          3.835800
# Type of Employment                 10.216750
# Location                            0.933250
# Loan Amount Request (USD)       88859.076706
# Current Loan Expenses (USD)       408.460440
# Expense Type 1                      0.359200
# Expense Type 2                      0.669150
# Dependents                          2.236900
# Credit Score                      738.791017
# No. of Defaults                     0.189500
# Has Active Credit Card              1.093200
# Property Age                     2534.097454
# Property Type                       2.471900
# Property Location                   0.989250
# Co-Applicant                        0.853486
# Property Price                 133466.497151
# dtype: float64

# %%
X_t['Property Price'].fillna(133466, inplace=True)
X_t['Co-Applicant'].fillna(1, inplace=True)

# %%
from sklearn.linear_model import Lasso
model = Lasso(alpha=1.0)
model.fit(X,y)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14527654508220.584, tolerance: 6896544949.552004
#   positive)
# Lasso()

# %%
y_predLassso=model.predict(X_t)

# %%
sample = pd.read_csv("../input/cipdata/test.csv")
sample['Loan Sanction Amount (USD)'] = y_predLassso
#sample.drop(["customer_visit_score","customer_product_search_score","customer_ctr_score","customer_stay_score","customer_frequency_score",
 #            "customer_product_variation_score","customer_order_score","customer_affinity_score","customer_active_segment","X1"], axis = 1, inplace = True) 
sample.drop(['Age', 'Income (USD)', 'Income Stability', 'Profession',
       'Type of Employment', 'Location', 'Loan Amount Request (USD)',
       'Current Loan Expenses (USD)', 'Expense Type 1', 'Expense Type 2',
       'Dependents', 'Credit Score', 'No. of Defaults',
       'Has Active Credit Card', 'Property Age', 'Property Type',
       'Property Location', 'Co-Applicant','Name','Gender','Property ID','Property Price'], axis = 1, inplace = True) 



sample.to_csv('Predictions.csv', header=True, index=False)
